# %% [markdown]
# # 🧪 Laboratório: O Desafio dos Tipos
#
# Bem-vindo ao laboratório do **nildo.pro.br**!
#
# Neste teste, vamos ver o que acontece quando tentamos somar um texto com um número sem converter.

# %%
# Tente rodar este código e veja o erro
valor_produto = "100"
desconto = 10

print(f"O preço final é: {valor_produto - desconto}")

# %% [markdown]
# ### 💡 Desafio:
# Use a função `int()` no `valor_produto` para que o Python consiga fazer a conta!
